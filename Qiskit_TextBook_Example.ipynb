# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.autograd import Function
from torchvision import datasets, transforms
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

import qiskit
from qiskit import transpile, assemble
from qiskit.visualization import *

# %%
class QuantumCircuit:
    """ 
    This class provides a simple interface for interaction 
    with the quantum circuit 
    """
    
    def __init__(self, n_qubits, backend, shots):
        # --- Circuit definition ---
        self._circuit = qiskit.QuantumCircuit(n_qubits)
        
        all_qubits = [i for i in range(n_qubits)]
        self.theta = qiskit.circuit.Parameter('theta')
        
        self._circuit.h(all_qubits)
        self._circuit.barrier()
        self._circuit.ry(self.theta, all_qubits)
        
        self._circuit.measure_all()
        # ---------------------------

        self.backend = backend
        self.shots = shots
    
    def run(self, thetas):
        t_qc = transpile(self._circuit,
                         self.backend)
        qobj = assemble(t_qc,
                        shots=self.shots,
                        parameter_binds = [{self.theta: theta} for theta in thetas])
        job = self.backend.run(qobj)
        result = job.result().get_counts(self._circuit)
        
        counts = np.array(list(result.values()))
        states = np.array(list(result.keys())).astype(float)
        
        # Compute probabilities for each state
        probabilities = counts / self.shots
        # Get state expectation
        expectation = np.sum(states * probabilities)

        
        return np.array([expectation])

# %%
simulator = qiskit.Aer.get_backend('qasm_simulator')

circuit = QuantumCircuit(1, simulator, 100)
print('Expected value for rotation pi {}'.format(circuit.run([np.pi])))
circuit._circuit.draw()
# Out:
# Expected value for rotation pi [0.47]
#         ┌───┐ ░ ┌───────────┐ ░ ┌─┐
#    q_0: ┤ H ├─░─┤ RY(theta) ├─░─┤M├
#         └───┘ ░ └───────────┘ ░ └╥┘
# meas: 1/═════════════════════════╩═
#                                  0

# %%
class HybridFunction(Function):
    """ Hybrid quantum - classical function definition """
    
    @staticmethod
    def forward(ctx, input, quantum_circuit, shift):
        """ Forward pass computation """
        ctx.shift = shift
        #print("the input is", input)
        ctx.quantum_circuit = quantum_circuit

        expectation_z = ctx.quantum_circuit.run(input[0].tolist())
        #print("the input is", input)
        result = torch.tensor([expectation_z])
        ctx.save_for_backward(input, result)

        return result
        
    @staticmethod
    def backward(ctx, grad_output):
        """ Backward pass computation """
        input, expectation_z = ctx.saved_tensors
        
        input_list = np.array(input.tolist())
        #print("the input:", input)
     
        shift_right = input_list + np.ones(input_list.shape) * ctx.shift
        shift_left = input_list - np.ones(input_list.shape) * ctx.shift
        
        gradients = []
        for i in range(len(input_list)):
            expectation_right = ctx.quantum_circuit.run(shift_right[i])
            expectation_left  = ctx.quantum_circuit.run(shift_left[i])
            
            gradient = torch.tensor([expectation_right]) - torch.tensor([expectation_left])
            gradients.append(gradient)
            #print("the gradients first are:",gradients)
        gradients = np.array([gradients])
        print("the gradient before is:", gradients)

        gradients=gradients.T
        #print("the gradient after is:", gradients)

        #print("the transformed gradients are:",gradients)
        returned=torch.tensor([gradients]).float() * grad_output.float()
        print("returned is:", returned)
        return returned, None, None

class Hybrid(nn.Module):
    """ Hybrid quantum - classical layer definition """
    
    def __init__(self, backend, shots, shift):
        super(Hybrid, self).__init__()
        self.quantum_circuit = QuantumCircuit(1, backend, shots)
        self.shift = shift
        
    def forward(self, input):
        return HybridFunction.apply(input, self.quantum_circuit, self.shift)

# %%
# Concentrating on the first 100 samples
n_samples = 100

X_train = datasets.MNIST(root='./data', train=True, download=True,
                         transform=transforms.Compose([transforms.ToTensor()]))

# Leaving only labels 0 and 1 
idx = np.append(np.where(X_train.targets == 0)[0][:n_samples], 
                np.where(X_train.targets == 1)[0][:n_samples])

X_train.data = X_train.data[idx]
X_train.targets = X_train.targets[idx]

train_loader = torch.utils.data.DataLoader(X_train, batch_size=1, shuffle=True)

# %%
n_samples_show = 6

data_iter = iter(train_loader)
fig, axes = plt.subplots(nrows=1, ncols=n_samples_show, figsize=(10, 3))

while n_samples_show > 0:
    images, targets = data_iter.__next__()

    axes[n_samples_show - 1].imshow(images[0].numpy().squeeze(), cmap='gray')
    axes[n_samples_show - 1].set_xticks([])
    axes[n_samples_show - 1].set_yticks([])
    axes[n_samples_show - 1].set_title("Labeled: {}".format(targets.item()))
    
    n_samples_show -= 1

# %%
n_samples = 50

X_test = datasets.MNIST(root='./data', train=False, download=True,
                        transform=transforms.Compose([transforms.ToTensor()]))

idx = np.append(np.where(X_test.targets == 0)[0][:n_samples], 
                np.where(X_test.targets == 1)[0][:n_samples])

X_test.data = X_test.data[idx]
X_test.targets = X_test.targets[idx]

test_loader = torch.utils.data.DataLoader(X_test, batch_size=1, shuffle=True)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 6, kernel_size=5)
        self.conv2 = nn.Conv2d(6, 16, kernel_size=5)
        self.dropout = nn.Dropout2d()
        self.fc1 = nn.Linear(256, 64)
        self.fc2 = nn.Linear(64, 1)
        self.hybrid = Hybrid(qiskit.Aer.get_backend('qasm_simulator'), 100, np.pi / 2)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = self.dropout(x)
        x = x.view(1, -1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        #print ("the ouput of the classical network is: %d", x); 
        x = self.hybrid(x)
        #print("before concatenation",x)
        x=torch.cat((x, 1 - x), -1)
        #print ("the ouput of the hybrid network is: %d", x); 
        return x

# %%
1-torch.tensor([[0.6000, 0.3]])
# Out:
# tensor([[0.4000, 0.7000]])

# %%
model = Net()
optimizer = optim.Adam(model.parameters(), lr=0.001)
loss_func = nn.NLLLoss()

epochs = 20
loss_list = []

model.train()
for epoch in range(epochs):
    total_loss = []
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad()
        # Forward pass
        output = model(data)
        # Calculating loss
        loss = loss_func(output, target)
        # Backward pass
        loss.backward()
        # Optimize the weights
        optimizer.step()
        
        total_loss.append(loss.item())
    loss_list.append(sum(total_loss)/len(total_loss))
    print('Training [{:.0f}%]\tLoss: {:.4f}'.format(
        100. * (epoch + 1) / epochs, loss_list[-1]))
# Out:
# the gradient before is: [[0.99]]
# returned is: tensor([[[0.9900]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[1.]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[-1.]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[1.]]])
# the gradient before is: [[0.99]]
# returned is: tensor([[[-0.9900]]])
# the gradient before is: [[0.99]]
# returned is: tensor([[[0.9900]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[1.]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[-1.]]])
# the gradient before is: [[0.99]]
# returned is: tensor([[[-0.9900]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[-1.]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[1.]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[1.]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[1.]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[1.]]])
# the gradient before is: [[0.99]]
# returned is: tensor([[[-0.9900]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[1.]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[-1.]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[1.]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[1.]]])
# the gradient before is: [[0.99]]
# returned is: tensor([[[0.9900]]])
# the gradient before is: [[0.98]]
# returned is: tensor([[[-0.9800]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[1.]]])
# the gradient before is: [[0.97]]
# returned is: tensor([[[0.9700]]])
# the gradient before is: [[0.98]]
# returned is: tensor([[[-0.9800]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[1.]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[-1.]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[-1.]]])
# the gradient before is: [[0.99]]
# returned is: tensor([[[0.9900]]])
# the gradient before is: [[0.98]]
# returned is: tensor([[[-0.9800]]])
# the gradient before is: [[0.99]]
# returned is: tensor([[[-0.9900]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[-1.]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[1.]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[1.]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[1.]]])
# the gradient before is: [[0.98]]
# returned is: tensor([[[0.9800]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[-1.]]])
# the gradient before is: [[0.97]]
# returned is: tensor([[[-0.9700]]])
# the gradient before is: [[0.87]]
# returned is: tensor([[[0.8700]]])
# the gradient before is: [[0.96]]
# returned is: tensor([[[0.9600]]])
# the gradient before is: [[0.97]]
# returned is: tensor([[[0.9700]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[1.]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[1.]]])
# the gradient before is: [[0.96]]
# returned is: tensor([[[0.9600]]])
# the gradient before is: [[0.84]]
# returned is: tensor([[[0.8400]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[-1.]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[-1.]]])
# the gradient before is: [[0.62]]
# returned is: tensor([[[0.6200]]])
# the gradient before is: [[1.]]
# returned is: tensor([[[-1.]]])
# the gradient before is: [[0.93]]
# returned is: tensor([[[-0.9300]]])
# the gradient before is: [[0.53]]
# returned is: tensor([[[0.5300]]])
# the gradient before is: [[0.59]]
# returned is: tensor([[[0.5900]]])
# the gradient before is: [[0.91]]
# returned is: tensor([[[-0.9100]]])
# the gradient before is: [[0.98]]
# returned is: tensor([[[-0.9800]]])
# the gradient before is: [[0.67]]
# returned is: tensor([[[0.6700]]])
# the gradient before is: [[0.76]]
# returned is: tensor([[[-0.7600]]])
# the gradient before is: [[0.56]]
# returned is: tensor([[[0.5600]]])
# the gradient before is: [[0.31]]
# returned is: tensor([[[0.3100]]])
# the gradient before is: [[0.88]]
# returned is: tensor([[[-0.8800]]])
# the gradient before is: [[0.94]]
# returned is: tensor([[[-0.9400]]])
# the gradient before is: [[0.93]]
# returned is: tensor([[[-0.9300]]])
# the gradient before is: [[0.31]]
# returned is: tensor([[[-0.3100]]])
# the gradient before is: [[0.7]]
# returned is: tensor([[[0.7000]]])
# the gradient before is: [[-0.29]]
# returned is: tensor([[[0.2900]]])
# the gradient before is: [[0.47]]
# returned is: tensor([[[-0.4700]]])
# the gradient before is: [[0.66]]
# returned is: tensor([[[0.6600]]])
# the gradient before is: [[0.49]]
# returned is: tensor([[[-0.4900]]])
# the gradient before is: [[0.88]]
# returned is: tensor([[[-0.8800]]])
# the gradient before is: [[0.45]]
# returned is: tensor([[[0.4500]]])
# the gradient before is: [[-0.75]]
# returned is: tensor([[[0.7500]]])
# the gradient before is: [[-0.88]]
# returned is: tensor([[[0.8800]]])
# the gradient before is: [[0.99]]
# returned is: tensor([[[0.9900]]])
# the gradient before is: [[0.15]]
# returned is: tensor([[[0.1500]]])
# the gradient before is: [[-0.21]]
# returned is: tensor([[[0.2100]]])
# the gradient before is: [[0.12]]
# returned is: tensor([[[-0.1200]]])
# the gradient before is: [[0.94]]
# returned is: tensor([[[0.9400]]])
# the gradient before is: [[0.67]]
# returned is: tensor([[[0.6700]]])
# the gradient before is: [[-0.28]]
# returned is: tensor([[[0.2800]]])
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\genericpath.py in isfile(path)
#      29     try:
# ---> 30         st = os.stat(path)
#      31     except OSError:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'C:\\Users\\joshr\\.qiskit\\settings.conf'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-719b6d3e9a3c> in <module>
#      16         loss = loss_func(output, target)
#      17         # Backward pass
# ---> 18         loss.backward()
#      19         # Optimize the weights
#      20         optimizer.step()
#
# ~\anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# ~\anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
# --> 132         allow_unreachable=True)  # allow_unreachable flag
#     133
#     134
#
# ~\anaconda3\lib\site-packages\torch\autograd\function.py in apply(self, *args)
#      87     def apply(self, *args):
#      88         # _forward_cls is defined by derived class
# ---> 89         return self._forward_cls.backward(self, *args)  # type: ignore
#      90
#      91
#
# <ipython-input-39-7b419ce4d206> in backward(ctx, grad_output)
#      30         for i in range(len(input_list)):
#      31             expectation_right = ctx.quantum_circuit.run(shift_right[i])
# ---> 32             expectation_left  = ctx.quantum_circuit.run(shift_left[i])
#      33
#      34             gradient = torch.tensor([expectation_right]) - torch.tensor([expectation_left])
#
# <ipython-input-19-3d2382bc4be8> in run(self, thetas)
#      24     def run(self, thetas):
#      25         t_qc = transpile(self._circuit,
# ---> 26                          self.backend)
#      27         qobj = assemble(t_qc,
#      28                         shots=self.shots,
#
# ~\anaconda3\lib\site-packages\qiskit\compiler\transpile.py in transpile(circuits, backend, basis_gates, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, seed_transpiler, optimization_level, pass_manager, callback, output_name)
#     222     if optimization_level is None:
#     223         # Take optimization level from the configuration or 1 as default.
# --> 224         config = user_config.get_config()
#     225         optimization_level = config.get('transpile_optimization_level', 1)
#     226
#
# ~\anaconda3\lib\site-packages\qiskit\user_config.py in get_config()
#     105     """
#     106     filename = os.getenv('QISKIT_SETTINGS', DEFAULT_FILENAME)
# --> 107     if not os.path.isfile(filename):
#     108         return {}
#     109     user_config = UserConfig(filename)
#
# ~\anaconda3\lib\genericpath.py in isfile(path)
#      28     """Test whether a path is a regular file"""
#      29     try:
# ---> 30         st = os.stat(path)
#      31     except OSError:
#      32         return False
#
# KeyboardInterrupt:

# %%
plt.plot(loss_list)
plt.title('Hybrid NN Training Convergence')
plt.xlabel('Training Iterations')
plt.ylabel('Neg Log Likelihood Loss')
# Out:
# Text(0, 0.5, 'Neg Log Likelihood Loss')

# %%
model.eval()
with torch.no_grad():
    
    correct = 0
    for batch_idx, (data, target) in enumerate(test_loader):
        output = model(data)
        
        pred = output.argmax(dim=1, keepdim=True) 
        correct += pred.eq(target.view_as(pred)).sum().item()
        
        loss = loss_func(output, target)
        total_loss.append(loss.item())
        
    print('Performance on test data:\n\tLoss: {:.4f}\n\tAccuracy: {:.1f}%'.format(
        sum(total_loss) / len(total_loss),
        correct / len(test_loader) * 100)
        )
# Out:
# Performance on test data:
# 	Loss: -0.9874
# 	Accuracy: 100.0%
